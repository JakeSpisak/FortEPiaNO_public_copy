# %%
import matplotlib
matplotlib.use("nbagg")
import matplotlib.pyplot as plt
import numpy as np

# %%
N=20
yv=np.linspace(0.01,20,N)
plt.loglog(yv, [y*y/(np.exp(y/1.4)+1) for y in yv],'bo-')
yv=np.logspace(-2,np.log10(20),N)
plt.loglog(yv, [y*y/(np.exp(y/1.4)+1) for y in yv],'ro-')
plt.show()
plt.close()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
folder="output"
zdat=np.loadtxt("%s/z.dat"%folder)
d1dat=np.loadtxt("%s/nuDens_diag1.dat"%folder)
d2dat=np.loadtxt("%s/nuDens_diag2.dat"%folder)
d3dat=np.loadtxt("%s/nuDens_diag3.dat"%folder)

# %%
for x in d3dat:
    plt.loglog(yv, [d/y**2 for y,d in zip(yv,x[1:])])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot([x[0] for x in zdat], [x[1] for x in zdat])
plt.ylim([0.999,1.401])
plt.xlim([0.05,30])
plt.xscale("log")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
[[y**2/d for y,d in zip(yv,x[1:])] for x in d1dat]
# Out:
# [[1.0,
#   1.000000030322299,
#   1.000000062155787,
#   1.0000000327379157,
#   1.0000000525597637,
#   1.0000000725321496,
#   1.0000000396015896,
#   0.999999737276022,
#   0.9999999591092038,
#   1.0000000000000004],
#  [1.0000782061157183,
#   0.999886644976003,
#   0.9999134314798025,
#   0.9998079316751342,
#   0.9996571823859026,
#   0.9996233211156328,
#   1.0001254600229363,
#   1.0019678633888027,
#   1.0096368422869724,
#   1.1324130589873966],
#  [1.0003834469752257,
#   0.9997640552302719,
#   0.9996035257384414,
#   0.9990647868402224,
#   0.9984898397831925,
#   0.9982638816011241,
#   0.9990235517868572,
#   1.001510391841286,
#   1.0099689439592396,
#   1.1374532648889792],
#  [1.000733838123496,
#   0.9995507026203044,
#   0.999282571915754,
#   0.9983384423994824,
#   0.9974363280571812,
#   0.9973790206895335,
#   0.9982941173773284,
#   1.0007581646817691,
#   1.0089566197303357,
#   1.1275034452277153],
#  [1.0009055192232412,
#   0.9993900100614657,
# ...

# %%
yv
# Out:
# array([1.00000000e-02, 2.23111111e+00, 4.45222222e+00, 6.67333333e+00,
#        8.89444444e+00, 1.11155556e+01, 1.33366667e+01, 1.55577778e+01,
#        1.77788889e+01, 2.00000000e+01])

# %%
np.logspace(np.log10(0.05),np.log10(30),1000)
# Out:
# array([ 0.05      ,  0.05032119,  0.05064445,  0.05096978,  0.05129721,
#         0.05162674,  0.05195838,  0.05229215,  0.05262807,  0.05296615,
#         0.0533064 ,  0.05364883,  0.05399346,  0.05434031,  0.05468939,
#         0.0550407 ,  0.05539428,  0.05575013,  0.05610826,  0.05646869,
#         0.05683144,  0.05719652,  0.05756394,  0.05793372,  0.05830588,
#         0.05868043,  0.05905739,  0.05943677,  0.05981858,  0.06020285,
#         0.06058958,  0.0609788 ,  0.06137052,  0.06176476,  0.06216153,
#         0.06256085,  0.06296273,  0.0633672 ,  0.06377426,  0.06418394,
#         0.06459625,  0.06501121,  0.06542883,  0.06584914,  0.06627214,
#         0.06669787,  0.06712633,  0.06755754,  0.06799152,  0.06842829,
#         0.06886786,  0.06931026,  0.0697555 ,  0.0702036 ,  0.07065458,
#         0.07110846,  0.07156525,  0.07202498,  0.07248766,  0.07295331,
#         0.07342195,  0.07389361,  0.07436829,  0.07484602,  0.07532683,
# ...
